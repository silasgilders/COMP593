# %% [markdown]
# <a href="https://colab.research.google.com/github/silasgilders/COMP593/blob/main/WEEK_4_ADVANCED_SQL_AND_FILES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-169460a8-0466-49fc-a206-a642606a93cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-169460a8-0466-49fc-a206-a642606a93cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving social_network.db to social_network.db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
                          id integer PRIMARY KEY NOT NULL,
                          user_id integer NOT NULL,
                          friend_id integer NOT NULL,
                          FOREIGN KEY (user_id) REFERENCES people (id),
                          FOREIGN KEY (friend_id) REFERENCES people (id)
                        );"""

#Once again, we will execute the query, persist the changes, and close our connection.
myCursor.execute(createRelationshipsTable)
myConnection.commit()
myConnection.close()

# %%
# Confirm the table was added to the DB as expected
myConnection = sqlite3.connect('social_network.db')
myCursor = myConnection.cursor()
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('relationships')")
print(myCursor.fetchone())
myConnection.close()
# Out:
# ('id, user_id, friend_id',)

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range

myConnection = sqlite3.connect('social_network.db')
myCursor = myConnection.cursor()

#Complete the below query
addRelationshipQuery=  """INSERT INTO relationships(user_id, friend_id)
            VALUES (?, ?);"""

for _ in range(1000):
  #Populate the arguments that will be used in the query
  user_id = randrange(1, 1001)
  
  friend_id = user_id
  while friend_id == user_id:
    friend_id = randrange(1, 1001)               
  
  args = (user_id, friend_id)

 
  myCursor.execute(addRelationshipQuery, args)

#Commit your changes and close the connection.
myConnection.commit()
myConnection.close()

# %%
import sqlite3
from pprint import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

selectStatement = """SELECT * FROM relationships
                     LIMIT 20 """


myCursor.execute(selectStatement)
results = myCursor.fetchall()
pprint(results)

myConnection.close
# Out:
# [(1, 338, 856),
#  (2, 790, 420),
#  (3, 432, 713),
#  (4, 827, 147),
#  (5, 953, 125),
#  (6, 204, 600),
#  (7, 363, 783),
#  (8, 154, 643),
#  (9, 312, 63),
#  (10, 719, 575),
#  (11, 611, 46),
#  (12, 651, 387),
#  (13, 1000, 370),
#  (14, 844, 566),
#  (15, 504, 440),
#  (16, 348, 304),
#  (17, 310, 125),
#  (18, 262, 419),
#  (19, 74, 512),
#  (20, 366, 626)]
# <function Connection.close>

# %% [markdown]
# ## Building our Report
#
# Now that our AI Matchmaker has generated our network of relationships, a marketing firm is offering us boatloads of cash for information about the amount of friends the users of our social network have.
#
# The request is to return the name of each user, and the total number of relationships they have made.
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %%
import sqlite3
from pprint import pprint
#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()



#Complete the below query
query =  """SELECT people.name, COUNT(relationships.id) FROM relationships
            LEFT JOIN people ON relationships.user_id = people.id
            GROUP BY relationships.user_id;
        """

myCursor.execute(query)
results = myCursor.fetchall()
pprint(results)

myConnection.close()

#Uncomment the below line after you have determined what the correct mode will be for your file pointer.
fp = open('report.txt', mode='a')


for result in results:
  reses = str(result)
  fp.write(reses)


fp.close()
  #You will want to write the results to the file pointer here.
  #Use the newline character \n to create a line break in each write() statement.
  #Use print() statements as sanity checks if you are unsure of the integrity of your data.

#Don't forget to close the file pointer after you have finished!
# Out:
# [('Anthony Dennis', 2),
#  ('Sherry Ross', 1),
#  ('Danielle Gordon', 3),
#  ('Nathan Smith', 2),
#  ('Lisa Stanley', 1),
#  ('Paul Brown', 3),
#  ('Allison Robinson', 3),
#  ('Christopher Walton', 2),
#  ('Vanessa Bailey', 1),
#  ('Jonathan Schwartz', 1),
#  ('Michael Parsons', 3),
#  ('Dustin Ramirez', 2),
#  ('Jason Johnson', 4),
#  ('Tracy Torres', 1),
#  ('Nicole Becker', 2),
#  ('Heidi Rose', 1),
#  ('Austin Simmons', 1),
#  ('Christopher Carter', 3),
#  ('Micheal Kirk', 1),
#  ('Rachel Alvarado MD', 2),
#  ('Kathryn Glenn', 1),
#  ('Melody Davis', 1),
#  ('Thomas Meyer', 2),
#  ('Marcus Gray', 1),
#  ('Juan Gay', 1),
#  ('Eugene Howard', 1),
#  ('Tina Graham', 2),
#  ('Heather Banks', 2),
#  ('Ashley Wagner', 1),
#  ('Colleen Cole', 2),
#  ('Holly Dean', 1),
#  ('Joseph Tyler', 2),
#  ('Margaret Roberson', 2),
#  ('Brandon Fuentes', 1),
#  ('Matthew Page', 1),
#  ('Diana Barnett', 1),
#  ('Curtis Smith', 1),
#  ('Melissa Adams', 1),
#  ('Chris Gordon', 2),
#  ('Daniel Shea', 1),
#  ('Sheri Ballard', 1),
#  ('Andrea Peterson', 2),
#  ('Erin Walker', 1),
#  ('Tony Mendoza', 2),
#  ('Philip Johnson', 1),
#  ('Terry Cline', 3),
#  ('David Klein', 1),
#  ('Mackenzie Reid', 1),
#  ('Jeanette Rogers', 1),
#  ('Brittany Watson', 2),
#  ('Michael Tyler', 1),
#  ('David Schroeder', 2),
#  ('Julian Hernandez', 1),
#  ('Dr. Felicia Shaw', 1),
#  ('Charles Livingston', 3),
#  ('Jessica Stevens', 1),
#  ('Sally Cox', 1),
#  ('Jennifer Andrews', 1),
#  ('Vanessa Blair', 1),
#  ('Roy Lee', 1),
#  ('Joshua Walsh', 2),
#  ('Jessica Gibson', 2),
#  ('Jamie Obrien', 3),
#  ('Martin Vang', 1),
#  ('Perry Turner', 2),
#  ('Karla Dominguez', 1),
#  ('Erin Lutz', 1),
#  ('Nicole Perez', 1),
#  ('Dominique Lopez', 1),
#  ('Sara Patton', 2),
#  ('Sheri Potter', 1),
#  ('Robert Schmidt', 1),
#  ('Edward Khan', 1),
#  ('Joshua Hanson', 2),
#  ('Carolyn Williamson', 1),
#  ('John Torres', 4),
#  ('Kimberly Harvey', 1),
#  ('Laura Mccoy', 2),
#  ('Jaclyn Simmons', 1),
#  ('Brandon Daniels', 1),
#  ('Heidi Alvarez', 2),
#  ('Raymond Cardenas DVM', 1),
#  ('Brian Richards', 2),
#  ('Michelle Harmon', 2),
#  ('Mr. Randall Perez', 2),
#  ('Bryan Thomas', 2),
#  ('Carmen Clements', 1),
#  ('Charles Mitchell', 1),
#  ('Lee Deleon', 1),
#  ('Vincent Davis', 1),
#  ('Robert Fisher', 1),
#  ('Michael Dennis', 1),
#  ('Patrick Sanchez', 3),
#  ('Nicholas Malone', 1),
#  ('William Lin', 1),
#  ('Sharon Walter', 1),
#  ('Gloria Kennedy', 1),
#  ('Curtis Rogers', 1),
#  ('Samantha Phillips', 1),
#  ('Bethany Jones', 2),
#  ('Samuel Ayala', 1),
#  ('Kevin Brown', 2),
#  ('Antonio James', 2),
#  ('April Montgomery', 2),
#  ('Joyce Newman', 1),
#  ('Mark Reynolds', 2),
#  ('Tommy Rivera', 1),
#  ('Michael Fitzgerald', 1),
#  ('Joshua Miller', 1),
#  ('Sarah Wood', 2),
#  ('Heather Riley', 2),
#  ('Debbie Aguirre', 1),
#  ('Nicole Day', 1),
#  ('Corey Johnson', 1),
#  ('Barbara West', 1),
#  ('Mrs. Anna Campbell', 1),
#  ('Crystal French', 1),
#  ('Sandra Mills', 2),
#  ('Michael Smith', 2),
#  ('Justin Avila', 3),
#  ('Cody Hill', 1),
#  ('Elijah Smith', 1),
#  ('Samantha Perry', 1),
#  ('Dr. Julie Tran', 1),
#  ('Patricia Cardenas', 2),
#  ('Karina Carlson', 2),
#  ('Christopher Wallace', 4),
#  ('Miranda Bray', 3),
#  ('Michael Coleman', 1),
#  ('Wendy Carlson', 1),
#  ('Kelly Christian', 2),
#  ('Christopher Wallace', 2),
#  ('Joshua Bradshaw', 1),
#  ('Leslie Sanchez', 1),
#  ('Dennis White', 1),
#  ('Laura Lewis', 3),
#  ('John Williams', 2),
#  ('Joshua Mejia', 1),
#  ('Darren Warren', 1),
#  ('Anne Frye', 1),
#  ('Matthew Davila', 1),
#  ('Danielle Smith', 3),
#  ('Misty Sosa', 2),
#  ('Tyler Nunez', 2),
#  ('Samantha Stein', 1),
#  ('David Lopez', 1),
#  ('Anthony Garrett', 1),
#  ('Shelia Barber', 1),
#  ('Kurt Brooks', 1),
#  ('Kelly Martin', 1),
#  ('Courtney Smith', 4),
#  ('Krista Miller', 1),
#  ('Andrew Cooper', 1),
#  ('Eric Smith', 2),
#  ('Mark Gross', 3),
#  ('Victoria Ortega', 1),
#  ('Christopher Wells', 1),
#  ('Paula Johnson', 1),
#  ('Ronald Osborne', 1),
#  ('Shawn Neal MD', 1),
#  ('Jason Cunningham', 1),
#  ('Barbara Ochoa', 1),
#  ('Laura Cohen', 1),
#  ('Jeffrey Hubbard', 1),
#  ('James Miller', 2),
#  ('James Clayton', 2),
#  ('Kimberly May', 2),
#  ('Catherine Nixon', 1),
#  ('Charles Smith', 1),
#  ('Mark Green', 2),
#  ('Yolanda Kirby', 3),
#  ('Brandon Adams', 1),
#  ('Renee White', 2),
#  ('Sue Ellis', 1),
#  ('Rebecca Baldwin', 2),
#  ('Becky Lopez', 1),
#  ('Bradley Bell', 3),
#  ('Casey Dickson', 1),
#  ('Stephanie Dawson', 3),
#  ('Veronica Alvarez', 1),
#  ('James Phillips', 1),
#  ('Cassandra Kane', 2),
#  ('Raymond Crawford', 3),
#  ('Summer Goodwin', 1),
#  ('Kevin Reyes', 5),
#  ('Nancy Maynard', 1),
#  ('Kelly Thomas', 1),
#  ('Jeffrey Cooper', 1),
#  ('Tammy Alvarado', 1),
#  ('Rebecca Gardner', 2),
#  ('James Hudson', 1),
#  ('Gordon Rice', 1),
#  ('Rose Hart', 1),
#  ('Sharon Davis', 1),
#  ('Shannon Mccall', 1),
#  ('Beverly Cain', 1),
#  ('Alyssa Huynh', 1),
#  ('David Campos', 3),
#  ('Linda Lopez', 3),
#  ('Daniel Herring', 1),
#  ('Susan Mcdaniel', 1),
#  ('Mary Franklin', 1),
#  ('Anthony Fisher', 3),
#  ('Matthew Ramirez', 1),
#  ('Monica Williams', 1),
#  ('Gary Bell', 2),
#  ('Tony Bauer', 2),
#  ('Terry Jennings', 1),
#  ('Eddie Wade', 1),
#  ('Ray Solis', 1),
#  ('Melissa Anderson', 1),
#  ('Kyle Ford', 1),
#  ('Thomas Kelley', 3),
#  ('John Glass', 1),
#  ('Jordan Mayer', 1),
#  ('Rachel Martinez', 1),
#  ('Ashley Hudson', 1),
#  ('David Lopez', 2),
#  ('Matthew Robinson', 3),
#  ('Vincent Miles', 1),
#  ('Joseph Knight Jr.', 2),
#  ('Ms. Dana Kelly', 1),
#  ('Rachael Williams', 3),
#  ('Dustin Lawson', 1),
#  ('James Matthews', 1),
#  ('Chad Crawford', 2),
#  ('Shari Sanchez', 1),
#  ('David Estes', 2),
#  ('Gloria Davidson', 2),
#  ('Donna Myers', 2),
#  ('Alejandro Simmons', 2),
#  ('Lauren Hernandez', 1),
#  ('Sarah Herrera', 2),
#  ('Tyler Phillips', 1),
#  ('Bobby Wilson', 1),
#  ('Tracy Woods', 1),
#  ('Maria Myers', 1),
#  ('Michael Richards', 1),
#  ('Heather Hall', 2),
#  ('Nicole George', 1),
#  ('John Taylor', 1),
#  ('Daniel Atkins', 2),
#  ('Kimberly Hernandez', 1),
#  ('Chad Arroyo', 1),
#  ('Donna Barnes', 2),
#  ('Annette Brown', 1),
#  ('Danielle Deleon', 1),
#  ('Steven Suarez', 1),
#  ('Jacqueline Martin', 2),
#  ('Sara Pratt', 2),
#  ('Krista Williams', 1),
#  ('Alexandra Obrien', 1),
#  ('Austin Delgado', 1),
#  ('John Smith', 2),
#  ('Mercedes Wilson', 1),
#  ('Katherine Delgado', 2),
#  ('Dr. Sabrina Waller', 1),
#  ('Nancy Thomas', 1),
#  ('Juan Taylor II', 1),
#  ('Zachary Martinez', 5),
#  ('Kevin Edwards', 2),
#  ('Ricardo Howard', 1),
#  ('Heather Gibson', 1),
#  ('Laura Rice', 2),
#  ('Vanessa Conley', 2),
#  ('Joseph Weber', 1),
#  ('Gina Thomas', 2),
#  ('Caleb Hoover', 2),
#  ('Beth Rosario', 1),
#  ('Rebecca Parker', 2),
#  ('Laura Taylor', 1),
#  ('Tom Murphy', 1),
#  ('Rodney Cobb', 1),
#  ('Kristina Morales', 2),
#  ('Jennifer Sanchez', 1),
#  ('Catherine Bell', 1),
#  ('Carol Perez', 1),
#  ('Lindsey Dominguez', 1),
#  ('Jerry Miller II', 2),
#  ('Patrick Fuller', 1),
#  ('Billy Jordan', 1),
#  ('Stephen Davis', 2),
#  ('Heather Hudson', 1),
#  ('Donald Carter', 2),
#  ('Allen Ramirez', 2),
#  ('Scott Moore', 1),
#  ('Corey Moore', 1),
#  ('Eric Brooks', 1),
#  ('James Ware', 2),
#  ('Kathryn Esparza', 1),
#  ('Jacob Sandoval', 2),
#  ('William Robinson', 1),
#  ('Matthew Smith', 1),
#  ('Daryl Davis', 2),
#  ('Darrell Stanley', 2),
#  ('Nicholas Carrillo', 1),
#  ('Kim Martinez', 2),
#  ('Nicole Gray', 3),
#  ('Mariah Evans', 1),
#  ('Karen Glass', 2),
#  ('Derek Haney', 2),
#  ('Jack Smith', 1),
#  ('Jonathan Peterson', 2),
#  ('Jon Flores', 1),
#  ('Erica Moses', 1),
#  ('Diane Dawson', 2),
#  ('Veronica Lee', 2),
#  ('Jordan Banks', 1),
#  ('Kathleen Perry', 1),
#  ('Kathleen Williams', 1),
#  ('Nicholas Keller', 2),
#  ('Shawn Cameron II', 1),
#  ('William Aguirre', 1),
#  ('Matthew Stevens', 1),
#  ('John Carr', 2),
#  ('Victor Hopkins', 1),
#  ('Robin Riley', 1),
#  ('Mark Anderson', 1),
#  ('Kimberly Richards', 1),
#  ('Andrew Campbell', 1),
#  ('Emily Meza', 1),
#  ('Benjamin Diaz', 2),
#  ('Vanessa Morrison', 1),
#  ('Hector Taylor', 1),
#  ('Anthony Young', 4),
#  ('Scott Nelson', 1),
#  ('Monica Mckinney', 2),
#  ('Mark Benitez', 1),
#  ('Michael Durham', 2),
#  ('Mary Colon', 2),
#  ('Diamond Johnson', 2),
#  ('Linda Davis', 1),
#  ('James Norton', 1),
#  ('Christina Cooley', 1),
#  ('Theresa Chambers MD', 1),
#  ('Mr. Dennis Deleon', 1),
#  ('Jeffrey Le', 1),
#  ('Kathy Garza', 2),
#  ('Melissa Li', 1),
#  ('Ashley Green', 1),
#  ('Jennifer Velasquez', 1),
#  ('Jessica Lewis', 1),
#  ('Amanda Rios', 1),
#  ('Lisa Wright', 2),
#  ('Craig Maldonado', 1),
#  ('Sheila Crawford', 4),
#  ('Daniel Gates', 1),
#  ('Kristen Evans', 3),
#  ('Mrs. Pamela Mendoza', 2),
#  ('Tracy Gutierrez', 2),
#  ('Victoria Khan', 3),
#  ('Lynn Martinez', 1),
#  ('Tina York', 2),
#  ('Christopher Lopez', 1),
#  ('James Morse', 2),
#  ('Daniel Delacruz', 2),
#  ('Amy Ross', 2),
#  ('Lawrence Thompson', 3),
#  ('Michael Anderson', 2),
#  ('Catherine Stark', 2),
#  ('Heather Lane', 1),
#  ('David Jones', 2),
#  ('Vicki Brady', 1),
#  ('John Rodriguez MD', 1),
#  ('Ashley Henry', 2),
#  ('David Burgess', 1),
#  ('Robert Anderson', 2),
#  ('Monique Williams', 1),
#  ('Alex Henry', 1),
#  ('Emily Jones', 1),
#  ('Peter Bailey', 2),
#  ('Heidi Terry', 2),
#  ('Destiny Hall', 1),
#  ('Aaron Velazquez', 1),
#  ('Alisha Hart', 1),
#  ('Elizabeth Sellers', 2),
#  ('Alan Weiss', 2),
#  ('Micheal Sanchez MD', 1),
#  ('Mrs. Maria Murphy DDS', 2),
#  ('Daniel Daniels', 1),
#  ('Frank Jackson', 1),
#  ('Bryan Richard', 2),
#  ('Kelsey Gonzalez', 1),
#  ('Cynthia Donaldson', 1),
#  ('Allen Forbes', 1),
#  ('Mark Pacheco', 1),
#  ('Jim Turner', 1),
#  ('Tammy Booker', 2),
#  ('Mr. Justin Russell', 1),
#  ('Jennifer Taylor', 2),
#  ('Jennifer Lee', 1),
#  ('Dawn Mitchell', 1),
#  ('Christopher Sanchez', 2),
#  ('Matthew Carlson', 1),
#  ('Destiny Webb', 1),
#  ('Susan Baldwin', 4),
#  ('Tiffany Vargas', 3),
#  ('Eric Phillips', 4),
#  ('Steven Burton', 1),
#  ('Stephanie Watkins', 1),
#  ('Tracy Jackson', 1),
#  ('James Gill', 3),
#  ('Alexandra Sullivan', 1),
#  ('Ronald Wade', 1),
#  ('Marvin Webster', 2),
#  ('Robin Lee', 2),
#  ('Beth Johnson', 1),
#  ('Gabriel Smith', 2),
#  ('Jessica Santiago', 1),
#  ('Oscar Mitchell', 1),
#  ('Erika Wilson', 2),
#  ('Justin Ruiz', 2),
#  ('Amanda Francis', 1),
#  ('Jordan Webster', 2),
#  ('Stacy Brown', 1),
#  ('Travis Bautista', 2),
#  ('Wanda Scott', 1),
#  ('David King', 4),
#  ('Joy Thompson', 1),
#  ('Paul Coleman', 1),
#  ('Monica Caldwell', 1),
#  ('Teresa Kane', 1),
#  ('Joseph Conner', 1),
#  ('Annette Valenzuela', 2),
#  ('Sandra Haynes', 2),
#  ('Kristin Tucker', 1),
#  ('Andrew Jacobson', 1),
#  ('Ryan Avery', 2),
#  ('Patrick Flores', 3),
#  ('Christopher Gonzales', 3),
#  ('Julia Nelson', 2),
#  ('Lori Aguilar', 1),
#  ('Carl Bowen', 2),
#  ('Jessica Hernandez', 4),
#  ('Jason Brown', 2),
#  ('Lisa Anderson', 2),
#  ('Rachel Mack', 2),
#  ('Cathy Glover', 2),
#  ('Crystal Hurley', 1),
#  ('Joseph Burgess', 1),
#  ('Amanda Hamilton', 2),
#  ('Christina Thompson', 1),
#  ('Morgan Donaldson', 1),
#  ('Mark Anderson', 1),
#  ('Rachael Reyes', 1),
#  ('Timothy Gilbert', 3),
#  ('Angela Gonzalez', 1),
#  ('Dana Patterson', 1),
#  ('Wayne Wheeler', 1),
#  ('Jeffrey Vargas', 2),
#  ('Felicia Walters', 1),
#  ('Jennifer Garcia', 1),
#  ('Ronald Johnson', 1),
#  ('Kathryn Morgan', 1),
#  ('Maurice Olsen', 1),
#  ('Jennifer Snyder', 1),
#  ('Wesley Weiss', 1),
#  ('Pamela Chen', 2),
#  ('Lisa Ryan', 2),
#  ('Arthur Mack', 1),
#  ('Jason Sanchez', 1),
#  ('Jennifer Ray', 1),
#  ('Melissa Solomon', 1),
#  ('Candace Andrade', 4),
#  ('Mr. Evan Davis MD', 1),
#  ('Drew Wilson', 2),
#  ('Christine Gomez', 1),
#  ('Mrs. Margaret Cooke DVM', 1),
#  ('Joseph Vaughan', 1),
#  ('Jared Cobb', 3),
#  ('Peter Hawkins', 2),
#  ('Nancy Simmons', 1),
#  ('Christine Campbell', 2),
#  ('Alexis Cantrell', 2),
#  ('Kathy Williams', 1),
#  ('Joshua Porter', 1),
#  ('Matthew Olson', 1),
#  ('Stephanie Smith', 1),
#  ('Jacob Burnett', 2),
#  ('Mrs. Rhonda Tran', 1),
#  ('Frank Nixon', 2),
#  ('Amanda Padilla', 1),
#  ('Ashley Jordan', 1),
#  ('Bridget Branch', 1),
#  ('Carol Burnett', 1),
#  ('Joshua Duke', 1),
#  ('Erin Harris', 1),
#  ('Charles Griffin', 2),
#  ('Jason Mayer', 4),
#  ('Denise Turner', 1),
#  ('Michael Alvarado', 2),
#  ('Benjamin Carter', 1),
#  ('Theodore Peterson Jr.', 2),
#  ('Eric Sanchez', 1),
#  ('Alexandra Rodriguez', 1),
#  ('Alejandro Ferguson', 3),
#  ('Paige Rios', 3),
#  ('Alexis Norton', 1),
#  ('Scott Vazquez', 1),
#  ('John Watson', 1),
#  ('Anne Silva', 4),
#  ('Jason Gonzalez', 2),
#  ('Marcus Choi', 1),
#  ('Jeremiah Gordon', 2),
#  ('James Thomas', 1),
#  ('Christopher Taylor', 1),
#  ('Jennifer Jackson', 2),
#  ('Virginia Arnold', 1),
#  ('Juan Kelly', 2),
#  ('Vanessa Hall', 1),
#  ('Heather White', 3),
#  ('Dustin Lopez', 1),
#  ('George Ramos', 3),
#  ('Ryan Marshall', 5),
#  ('Sheri Brown', 2),
#  ('Lisa Kelly', 2),
#  ('Robert Scott', 2),
#  ('William Crawford', 1),
#  ('Kenneth Rogers', 2),
#  ('Raymond Davis', 1),
#  ('Daniel Hayes', 1),
#  ('Nicole Faulkner', 1),
#  ('Angel Ortiz', 2),
#  ('Rebecca Johnson', 1),
#  ('Lindsay Flores', 1),
#  ('Timothy Murray', 1),
#  ('Amanda Graham', 1),
#  ('Beth Brown', 1),
#  ('Melissa Alexander', 1),
#  ('Daniel Olson', 1),
#  ('Matthew Swanson', 1),
#  ('Jacob Love', 2),
#  ('Shelley Church', 1),
#  ('Eric Mitchell', 3),
#  ('Nicole Johnson', 4),
#  ('Jason Jenkins', 1),
#  ('Richard Hill', 1),
#  ('Amy Short', 1),
#  ('Anna Hernandez', 3),
#  ('Brenda Adams', 1),
#  ('Sierra Morris', 1),
#  ('Jenna Porter', 2),
#  ('Miss Andrea Santiago', 1),
#  ('Kristen Hernandez', 1),
#  ('Misty Stevenson', 2),
#  ('Helen Murphy', 2),
#  ('Jane Ramirez', 1),
#  ('Anthony Briggs', 1),
#  ('Michael Stokes', 1),
#  ('Heather Delacruz', 1),
#  ('Benjamin Little', 1),
#  ('Amy Hawkins', 2),
#  ('Justin Payne', 1),
#  ('Erica Romero', 1),
#  ('April Chavez', 2),
#  ('Tina Logan', 1),
#  ('Kimberly Rice', 1),
#  ('James Graves', 1),
#  ('Samantha Snyder', 1),
#  ('Michael Cooper', 1),
#  ('Mckenzie Walker', 1),
#  ('Melissa Flores', 1),
#  ('Kathy Hudson', 1),
#  ('Andrea Gonzalez', 1),
#  ('Helen Gomez', 1),
#  ('Tammy Scott', 1),
#  ('Billy Lee', 1),
#  ('John Miller', 1),
#  ('Lori Colon', 1),
#  ('Leslie Kelly', 2),
#  ('Jeanne Gonzalez', 1),
#  ('Bonnie Carter', 1),
#  ('Nancy Harper', 2),
#  ('Samantha Collins', 1),
#  ('Amanda Douglas', 2),
#  ('Michael Jennings', 1),
#  ('Devon Hart', 2),
#  ('Melissa Clark', 1),
#  ('Sheila Crosby', 2),
#  ('Michaela Jacobs', 3),
#  ('Glenn Wilson', 1),
#  ('Dana Bass', 1),
#  ('Penny Berger DDS', 1),
#  ('Kenneth Gonzalez PhD', 1),
#  ('Amanda Roth', 1),
#  ('Matthew Vargas', 1),
#  ('Theodore Walker', 4),
#  ('Juan Davis', 1),
#  ('Stephanie Evans', 1),
#  ('Valerie Johnston', 1),
#  ('Diana Ramos', 1),
#  ('Madison Ware MD', 1),
#  ('Mrs. Stephanie Johnson DDS', 2),
#  ('Andrew Parsons', 1),
#  ('Gregory White', 1),
#  ('Jacqueline Snyder', 2),
#  ('Troy Goodman', 1),
#  ('John Glover', 1),
#  ('Julie Harris', 2),
#  ('Shannon Schneider', 2),
#  ('Michael Mann', 1),
#  ('Amanda Salas', 1),
#  ('Jason Robbins', 1),
#  ('Alan Jones', 2),
#  ('Willie Jordan', 2),
#  ('Kaitlin Blackwell', 2),
#  ('Angel Rowland', 1),
#  ('Thomas Clayton', 2),
#  ('Danielle Watson', 3),
#  ('Wanda Jordan', 1),
#  ('Paul Rosales', 2),
#  ('Timothy Stevens', 1),
#  ('Michele Estrada', 4),
#  ('Katherine Nelson', 2),
#  ('Travis Russell', 1),
#  ('Robin Lucas MD', 1),
#  ('Linda Hernandez', 1),
#  ('Jennifer Parker', 2),
#  ('Kelsey Moore', 2),
#  ('John Nash', 2),
#  ('Donna Cobb', 1),
#  ('Ashlee Robinson', 1),
#  ('Lauren Tucker', 2),
#  ('Emily Williams', 2),
#  ('Michael Beasley', 1),
#  ('Hayden Green', 5),
#  ('Brenda Smith', 2),
#  ('Alexander Blair', 3),
#  ('Gabriella Henderson', 1),
#  ('Angela Smith', 1),
#  ('Ronald Stout', 1),
#  ('Steven Lewis', 5),
#  ('Diane Gonzalez', 1),
#  ('Elizabeth Ward', 2),
#  ('Beth Brown', 1),
#  ('Kimberly Gonzalez', 1),
#  ('Steven Johnson', 2),
#  ('Robert Long', 2),
#  ('Shannon Hill', 1),
#  ('Peter Miller', 3),
#  ('Frank Sanders', 1),
#  ('Thomas Hudson', 1),
#  ('Kimberly Avila', 1),
#  ('Jason Martinez', 3),
#  ('Michael Blankenship', 3),
#  ('Cody Hubbard', 2),
#  ('Elizabeth Thompson', 1),
#  ('Nancy Durham', 1),
#  ('Lawrence Jensen', 1),
#  ('Chelsea Mckee', 2)]

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
